# %%
import numpy as np
import matplotlib.pyplot as plt
from random import randint
from math import pi as PI
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.kernel_ridge import KernelRidge
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold 
from sklearn.model_selection import RepeatedKFold
from sklearn.metrics import accuracy_score
from sklearn.model_selection import LeaveOneOut
from mlxtend.evaluate import bias_variance_decomp
import warnings
warnings.filterwarnings('ignore')
from sklearn.datasets import load_boston
from sklearn.svm import SVR
from sklearn.model_selection import validation_curve

# %% [markdown]
# **Train Test Split**

# %%
rng = np.random.RandomState(1)
X = np.sort(5 * rng.rand(80, 1), axis=0)
y = np.sin(X).ravel()
# Add noise to targets
y[::5] += 3 * (0.5 - rng.rand(16))

# %%
plt.scatter(X, y, edgecolor = 'black', c = 'grey', s=20)
plt.title('Simulation Data')
plt.xlabel('X')
plt.ylabel('y')
# plt.legend()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.5,
                                                    random_state=123,
                                                    shuffle=True)

# %%
# X_train= X_train.reshape(-1, 1)
# y_train= y_train.reshape(-1, 1)
# X_test = X_test.reshape(-1, 1)
# kf = RepeatedKFold(n_splits=2, n_repeats=2, random_state=None)

# %%
bias_clf, var_clf,mse_clf, = [], [], []
# alpha_list = [1, 10, 100]
alpha_list = [i for i in np.arange(0.0001, 0.01, 0.0001)]
for alp in alpha_list:
#     clf = KernelRidge()
    clf = KernelRidge(kernel = 'rbf', alpha = alp)
    clf.fit(X_train, y_train)
    pred_train = clf.predict(X_train)
    mse, bias, var = bias_variance_decomp(clf, X_train, y_train, X_test, y_test, loss='mse', num_rounds=200, random_seed=123)
    bias_clf.append(bias)
    var_clf.append(var)
    mse_clf.append(mse)

# %%
plt.plot(mse_clf, label = 'MSE')
plt.plot(bias_clf, label = 'Bias^2')
plt.plot(var_clf, label = 'Variance')
plt.legend()
plt.title('Bias Variance Trade off 50% test size')
plt.xlabel('Model Complexity')
plt.ylabel('Error')
plt.legend()
plt.show()

# %%
print("Best fit polynomial degree: ", mse_clf.index(min(mse_clf)))
# Out:
# Best fit polynomial degree:  98

# %%
# run train test split on real data
boston = load_boston()
X, y = boston.data, boston.target
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.5,
                                                    random_state=123,
                                                    shuffle=True)
bias_clf, var_clf,mse_clf, = [], [], []
# alpha_list = [i for i in np.arange(100000, 10000000000, 50000000)]
# alpha_list = [1000000, 100000000, 10000000000]
alpha_list = [100000, 150000, 1000000, 1500000, 10000000, 100000000, 10000000000, 1000000000000, 10000000000000]
for alp in alpha_list:
    clf = KernelRidge(kernel = 'polynomial', alpha = alp)
    clf.fit(X_train, y_train)
    pred_train = clf.predict(X_train)
    mse, bias, var = bias_variance_decomp(clf, X_train, y_train, X_test, y_test, num_rounds=200, loss='mse', random_seed=123)
    bias_clf.append(bias)
    var_clf.append(var)
    mse_clf.append(mse)

# %%
plt.plot(mse_clf, label = 'MSE')
plt.plot(bias_clf, label = 'Bias^2')
plt.plot(var_clf, label = 'Variance')
plt.legend()
plt.title('Bias Variance Trade off of Boston Data Using train_test_split')
plt.xlabel('Model Complexity')
plt.ylabel('Error')
plt.legend()
plt.show()

# %%
print("Best fit polynomial degree: ", mse_clf.index(min(mse_clf)))
# Out:
# Best fit polynomial degree:  5

# %% [markdown]
# **Run again for K fold**

# %%
rng = np.random.RandomState(1)
X = np.sort(5 * rng.rand(80, 1), axis=0)
y = np.sin(X).ravel()
y[::5] += 3 * (0.5 - rng.rand(16))

# %%
kf = RepeatedKFold(n_splits=2, n_repeats=1, random_state=None) 

for train_index, test_index in kf.split(X):
#       print("Train:", train_index, "Validation:",test_index)
      X_train, X_test = X[train_index], X[test_index] 
      y_train, y_test = y[train_index], y[test_index]

# %%
bias_clf, var_clf,mse_clf, = [], [], []
# alpha_list = [1, 100, 1000]
alpha_list = [i for i in np.arange(0.00001, 0.001, 0.000005)]
for alp in alpha_list:
    clf = KernelRidge(kernel = 'rbf', alpha = alp)
    clf.fit(X_train, y_train)
    pred_train = clf.predict(X_train)
    mse, bias, var = bias_variance_decomp(clf, X_train, y_train, X_test, y_test, loss='mse', num_rounds=200, random_seed=123)
    bias_clf.append(bias)
    var_clf.append(var)
    mse_clf.append(mse)

# %%
plt.plot(mse_clf, label = 'MSE')
plt.plot(bias_clf, label = 'Bias^2')
plt.plot(var_clf, label = 'Variance')
plt.title('Bias Variance Trade off Using KFold')
plt.xlabel('Model Complexity')
plt.ylabel('Error')
plt.legend()
plt.show()

# %%
print("Best fit polynomial degree: ", mse_clf.index(min(mse_clf)))
# Out:
# Best fit polynomial degree:  197

# %%
# run KFold on real data
boston = load_boston()
X, y = boston.data, boston.target
kf = RepeatedKFold(n_splits=2, n_repeats=1, random_state=None) 

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index] 
    y_train, y_test = y[train_index], y[test_index]
bias_clf, var_clf,mse_clf, = [], [], []
# alpha_list = [i for i in np.arange(100000, 1000000000000, 10000000)]
alpha_list = [10000, 100000, 150000, 1000000, 1500000, 10000000, 100000000, 10000000000, 1000000000000]
for alp in alpha_list:
    clf = KernelRidge(kernel = 'polynomial', alpha = alp)
    clf.fit(X_train, y_train)
    pred_train = clf.predict(X_train)
    mse, bias, var = bias_variance_decomp(clf, X_train, y_train, X_test, y_test, loss='mse', random_seed=123)
    bias_clf.append(bias)
    var_clf.append(var)
    mse_clf.append(mse)

# %%
print("Best fit polynomial degree: ", mse_clf.index(min(mse_clf)))
# Out:
# Best fit polynomial degree:  6

# %%
plt.plot(mse_clf, label = 'MSE')
plt.plot(bias_clf, label = 'Bias^2')
plt.plot(var_clf, label = 'Variance')
plt.title('Bias Variance Trade off of Boston Data Using KFold')
plt.xlabel('Model Complexity')
plt.ylabel('Error')
plt.legend()
plt.show()

# %% [markdown]
# **Run again for LOO**

# %%
rng = np.random.RandomState(1)
X = np.sort(5 * rng.rand(80, 1), axis=0)
y = np.sin(X).ravel()
y[::5] += 3 * (0.5 - rng.rand(16))

# %%
loo = LeaveOneOut()
loo.get_n_splits(X)
# Out:
# 80

# %%
for train_index, test_index in loo.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

# %%
# X_train= X_train.reshape(-1, 1)
# y_train= y_train.reshape(-1, 1)
# X_test = X_test.reshape(-1, 1)

# %%
bias_clf, var_clf,mse_clf, = [], [], []
# alpha_list = [1, 100, 1000]
alpha_list = [i for i in np.arange(0.01, 3, 0.01)]
# alpha_list = [i for i in np.arange(0.01, 3, 0.01)]
for alp in alpha_list:
    clf = KernelRidge(kernel = 'rbf', alpha = alp)
    clf.fit(X_train, y_train)
    pred_train = clf.predict(X_train)
    mse, bias, var = bias_variance_decomp(clf, X_train, y_train, X_test, y_test, loss='mse', num_rounds=200, random_seed=123)
    bias_clf.append(bias)
    var_clf.append(var)
    mse_clf.append(mse)

# %%
print("Best fit polynomial degree: ", mse_clf.index(min(mse_clf)))
# Out:
# Best fit polynomial degree:  6

# %%
plt.plot(mse_clf, label = 'MSE')
plt.plot(bias_clf, label = 'Bias^2')
plt.plot(var_clf, label = 'Variance')
plt.title('Bias Variance Trade off Using LeaveOneOut')
plt.xlabel('Model Complexity')
plt.ylabel('Error')
plt.legend()
plt.show()

# %%
# run LOO on real data
boston = load_boston()
X, y = boston.data, boston.target
loo = LeaveOneOut()
loo.get_n_splits(X)
# Out:
# 506

# %%
for train_index, test_index in loo.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

# %%
bias_clf, var_clf,mse_clf, = [], [], []
# alpha_list = [i for i in np.arange(0.01, 2, 0.01)]
alpha_list = [0.0001, 0.001, 0.01, 0.1, 1, 10000, 100000, 150000, 1000000, 100000000]
for alp in alpha_list:
    clf = KernelRidge(kernel = 'polynomial', alpha = alp)
    clf.fit(X_train, y_train)
    pred_train = clf.predict(X_train)
    mse, bias, var = bias_variance_decomp(clf, X_train, y_train, X_test, y_test, loss='mse', random_seed=123)
    bias_clf.append(bias)
    var_clf.append(var)
    mse_clf.append(mse)

# %%
print("Best fit polynomial degree: ", mse_clf.index(min(mse_clf)))
# Out:
# Best fit polynomial degree:  8

# %%
plt.plot(mse_clf, label = 'MSE')
plt.plot(bias_clf, label = 'Bias^2')
plt.plot(var_clf, label = 'Variance')
plt.title('Bias Variance Trade off of Boston Data Using LeaveOneOut')
plt.xlabel('Model Complexity')
plt.ylabel('Error')
plt.legend()
plt.show()

# %%
# alpha_list = [i for i in np.arange(0.001, 2, 0.001)]
# training_accuracy = []
# variance_list = []
# bias_list = []
# mse_list = []
# for alp in alpha_list:
#     clf = KernelRidge(kernel = 'rbf', alpha = alp)
#     clf.fit(X_train, y_train)
#     pred_train = clf.predict(X_train)
#     scores = clf.score(y_train, pred_train)
#     training_accuracy.append(scores)
#     variance = np.var(pred_train)
#     variance_list.append(variance)
#     bias = (np.mean((np.mean(pred_train) - y)**2) - variance)*2
#     bias_list.append(bias)
#     mse = bias + variance
#     mse_list.append(mse)

# %% [markdown]
# **SVM**

# %%
rng = np.random.RandomState(1)
X = np.sort(5 * rng.rand(80, 1), axis=0)
y = np.sin(X).ravel()
# Add noise to targets
y[::5] += 3 * (0.5 - rng.rand(16))

# %%
svr_rbf = SVR(kernel="rbf", C=100, gamma=0.1, epsilon=0.1)
pred = svr_rbf.fit(X, y).predict(X)

# %%
plt.scatter(X, y, s=20, edgecolor="black", c="grey", label = 'Data')
plt.plot(X, pred, color = 'steelblue', label='SVM')
plt.title('Support Vector Machine')
# plt.xlabel('Model Complexity')
# plt.ylabel('Error')
plt.legend()
plt.show()
